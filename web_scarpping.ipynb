# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse 
import urllib.request

# %%
names = []
prices = []           
descriptions = []
websites = []

# %%
root_url = 'https://jmty.jp/'
relative_url = 'saitama/sale-bic/g-all/a-179-saitama/p-'
url_combined = []

for link in relative_url:
  url_combined.append(urllib.parse.urljoin(root_url,link))

# %%
for i in range (1,5):
  website = 'https://jmty.jp/saitama/sale-bic/g-all/a-179-saitama/p-' + str(i)
  response = requests.get(website)
  soup = BeautifulSoup(response.content,'html.parser')
  items = soup.find_all('li',{'class': 'p-articles-list-item'})
  for  item in items:

    try:
        names.append(item.find('div',{'class':'p-item-title'}).get_text().strip())
    except:
        names.append("n/a")

    try:
        prices.append(item.find('div',{'class':'p-item-most-important'}).get_text().strip())
    except:  
        prices.append("n/a")

    try:
        descriptions.append(item.find('div',{'class':'p-item-detail'}).get_text().strip())
    except:
        descriptions.append("n/a")

    try:
        way_to_link = item.find('div',{'class':'p-item-title'})
        websites.append(way_to_link.find('a').get('href'))
    except:
        websites.append('n/a')

# %%
product_overview = pd.DataFrame({"name":names, "prices":prices, "descriptions": descriptions, "website": websites})
product_overview
# Out:
#                                     name                   prices  \
# 0     送料無料❗️🌈3月スペシャル🌈限定数のみ❗️31000円〜電動...                  31,000円
# 1            BELL ヘルメット 子供 ZOOM ズーム XS/S                     700円
# 2    送料無料❗️🌈3月スペシャル🌈限定数のみ❗️31000円〜電動ア...                  31,000円
# 3    関東全域送料無料 保証付き 電動自転車　ヤマハ　パスキッスミニ　...                  63,000円
# 4    🌈3月限定🌈在庫処分❗️売り切れ必死❗️電動アシスト自転車🚲を格...                  25,000円
# ..                                   ...                      ...
# 227                【ネット決済】クロスバイク　raleigh                  10,000円
# 228                  新品★ロードバイク　ヘルメット 安全帽                   1,000円
# 229  クロスバイク　RITEWAY PASTURE ライトウェイ　パスチャー                  15,000円
# 230  ダイハツ エッセ ＶＳ　メモリアルエディション　電動格納ミラー　...  218,000円 64,600km 2008年
# 231         LOUIS GARNEAU LGS-TR2 クロスバイク                  15,000円
#
#                                           descriptions  \
# 0    ★業界最安値に挑戦中💪\r\n★動作確認済み✨\r\n★中古品で構わないから安く欲しい！とい...
# 1    ダメージは小傷のみ。\n\n検）働く車 はたらく車 働くクルマ はたらくクルマ 働くくるま ...
# 2    ★業界最安値に挑戦中💪\r\n★動作確認済み✨\r\n★中古品で構わないから安く欲しい！とい...
# 3    安心、安全もお届けする為是非当店プロフィールもご覧になってみてください。\n\n■■■■■■...
# 4    ★業界最安値に挑戦中💪\r\n★動作確認済み✨\r\n★中古品で構わないから安く欲しい！とい...
# ..                                                 ...
# 227  何年か乗っていたクロスバイクです。\n\n知人から購入したので、年式等は不明です。\n故障は...
# 228  サイズ　M. Lあります\n\nシールドフェイス付き　通常用と光遮断用の二つ付き\n\n詳し...
# 229  多少使用感あります。\r\n変速機のカバー？が無いです。変速機能自体は問題ないです。\r\n...
# 230  ■　支払総額:  21.8万円\n■　車両本体価格：　98,000 円\n■　メーカー名：　...
# 231  ルイガノ　LGS-TR2\r\n\r\n420mm（適正身長155〜175センチ）\r\n7...
#
#                                                website
# 0                                     /my/payments/new
# 1       https://jmty.jp/saitama/sale-bic/article-zsco0
# 2      https://jmty.jp/kanagawa/sale-bic/article-w1mkn
# 3       https://jmty.jp/saitama/sale-bic/article-xmr2d
# 4       https://jmty.jp/saitama/sale-bic/article-pckrg
# ..                                                 ...
# 227     https://jmty.jp/saitama/sale-bic/article-w9sro
# 228     https://jmty.jp/saitama/sale-bic/article-ncdla
# 229     https://jmty.jp/saitama/sale-bic/article-vx6v3
# 230  https://jmty.jp/saitama/car-dai/alliance-g_700...
# 231     https://jmty.jp/saitama/sale-bic/article-vujgx
#
# [232 rows x 4 columns]

# %%
product_overview.to_excel('web_scrapping_to_find_bicycle.xlsx', index=False)
